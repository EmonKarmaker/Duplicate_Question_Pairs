# %%
import numpy as np
import pandas as pd
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv('dataset/train.csv')

# %%
df.shape
# Out:
# (404290, 6)

# %%
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
new_df=df.sample(30000)

# %%
new_df.isnull().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       0
# question2       0
# is_duplicate    0
# dtype: int64

# %%
new_df.duplicated().sum()
# Out:
# 0

# %%
ques_df=new_df[['question1','question2']]
ques_df.head()
# Out:
#                                                 question1  \
# 89284               What do Saudis think about Yemen war?
# 119802                       Is anonymous 100% anonymous?
# 193211                Would you marry a non-virgin woman?
# 277704  How do people who are born deaf and blind live...
# 373221  What are President Obama's strengths and weakn...
#
#                                                 question2
# 89284   What do you think about the WAR between Yemen ...
# 119802                     Is anonymous really anonymous?
# 193211          Would you marry a girl who is not virgin?
# 277704  Are there any ideas to help cure the blind, de...
# 373221  What do people who don't live in the U.S. thin...

# %%
from sklearn.feature_extraction.text import CountVectorizer
questions=list(ques_df['question1'])+list(ques_df['question2'])
cv=CountVectorizer(max_features=3000)
q1_arr,q2_arr=np.vsplit(cv.fit_transform(questions).toarray(),2)

# %%
temp_df1=pd.DataFrame(q1_arr, index=ques_df.index)
temp_df2=pd.DataFrame(q2_arr, index=ques_df.index)
temp_df=pd.concat([temp_df1,temp_df2],axis=1)
temp_df.shape
# Out:
# (30000, 6000)

# %%
temp_df['is_duplicate']=new_df['is_duplicate']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(temp_df.iloc[:,0:-1].values,temp_df.iloc[:,-1].values,test_size=0.2,random_state=1)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
rf=RandomForestClassifier()
rf.fit(X_train,y_train)
y_pred=rf.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.7336666666666667

# %%
# !pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\tensorflow\tf_gpu_py310\lib\site-packages (3.1.1)
# Requirement already satisfied: numpy in c:\tensorflow\tf_gpu_py310\lib\site-packages (from xgboost) (1.26.4)
# Requirement already satisfied: scipy in c:\tensorflow\tf_gpu_py310\lib\site-packages (from xgboost) (1.15.3)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from xgboost import XGBClassifier 
xgb=XGBClassifier()
xgb.fit(X_train,y_train)
y_pred=xgb.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.729
